# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'Python'})

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965
# 2020-01-03  0.491541 -1.508727  1.005869 -1.422467
# 2020-01-04 -0.530700 -0.573451  1.761152 -1.002568
# 2020-01-05 -0.083414  1.235264  0.276845  1.579281
# 2020-01-06  0.057760  0.404265 -1.412687  1.213337

# %%
df.shape
# Out:
# (6, 4)

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df2
# Out:
#      A          B    C  D      E       F
# 0  1.0 2013-01-02  1.0  3   test  Python
# 1  1.0 2013-01-02  1.0  3  train  Python
# 2  1.0 2013-01-02  1.0  3   test  Python
# 3  1.0 2013-01-02  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965
# 2020-01-03  0.491541 -1.508727  1.005869 -1.422467
# 2020-01-04 -0.530700 -0.573451  1.761152 -1.002568
# 2020-01-05 -0.083414  1.235264  0.276845  1.579281
# 2020-01-06  0.057760  0.404265 -1.412687  1.213337

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146    NaN
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965    NaN
# 2020-01-03  0.491541 -1.508727  1.005869 -1.422467    NaN
# 2020-01-04 -0.530700 -0.573451  1.761152 -1.002568    NaN

# %%
df1.loc[datas[0]:datas[1], 'Var_E'] = 77

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146   77.0
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965   77.0
# 2020-01-03  0.491541 -1.508727  1.005869 -1.422467    NaN
# 2020-01-04 -0.530700 -0.573451  1.761152 -1.002568    NaN

# %%
df1.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# Var_E    float64
# dtype: object

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean   0.272147 -1.018669  0.425052 -0.757054   77.0
# std    0.565276  0.780025  1.148903  0.808131    0.0
# min   -0.530700 -1.828697 -0.541635 -1.422467   77.0
# 25%    0.126163 -1.588719 -0.529292 -1.122976   77.0
# 50%    0.418329 -1.041089  0.240346 -1.012857   77.0
# 75%    0.564313 -0.471039  1.194690 -0.646935   77.0
# max    0.782628 -0.163804  1.761152  0.419965   77.0

# %%
# dados missing

# %%
df1.isna().sum()
# Out:
# Var_A    0
# Var_B    0
# Var_C    0
# Var_D    0
# Var_E    2
# dtype: int64

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146   77.0
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965   77.0
# 2020-01-03  0.491541 -1.508727  1.005869 -1.422467    NaN
# 2020-01-04 -0.530700 -0.573451  1.761152 -1.002568    NaN

# %%
df1.dropna(axis=0, how='any')
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.345118 -0.163804 -0.525178 -1.023146   77.0
# 2020-01-02  0.782628 -1.828697 -0.541635  0.419965   77.0

# %%
df1.dropna(axis=1, how='any')
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.108054  0.451149 -0.476590  1.646939
# 2020-01-02  2.033522  1.130295  0.393841 -0.872713
# 2020-01-03 -1.021104  0.221334  1.535066 -0.902563
# 2020-01-04  0.927034 -0.568369  0.247304  0.709899
