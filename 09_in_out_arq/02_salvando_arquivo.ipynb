# %%
import pandas as pd

# %%
d1 = pd.read_excel('dados_3.xlsx')

# %%
d1.head(2)
# Out:
#    CÓDIGO               SETOR  PREÇO ATUAL  ...      VPA  P/VPA      DY
# 0  ABCP11           Shoppings        94.52  ...    74.53   1.27  0.0066
# 1  ALMI11  Lajes Corporativas      1378.49  ...  1713.48   0.80     NaN
#
# [2 rows x 20 columns]

# %%
d1.shape
# Out:
# (11, 20)

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.to_csv('teste.csv')
