# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20180101', periods = 600, freq="D")

df = pd.DataFrame(np.random.randn(600,5), index = datas, columns = list("ABCDE"))

# %%
df.head(2)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246

# %%
df['D'].head(5)
# Out:
# 2018-01-01    0.723208
# 2018-01-02    2.314951
# 2018-01-03   -1.682846
# 2018-01-04    0.586609
# 2018-01-05    1.290251
# Freq: D, Name: D, dtype: float64

# %%
df.head(10)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039
# 2018-01-04  1.888237 -1.173886  0.247253  0.586609 -0.583093
# 2018-01-05 -1.173853  0.951275  0.344095  1.290251 -0.230119
# 2018-01-06  0.258717 -0.458210  0.561895  0.063986 -0.069068
# 2018-01-07  0.210527  1.068722 -1.311264  0.582808 -0.777233
# 2018-01-08 -1.260806 -1.280222 -0.743041  0.265606  0.981799
# 2018-01-09 -0.221860  0.237651  1.261305  0.349872 -1.604458
# 2018-01-10 -1.113097 -0.254874 -0.321270 -0.049824  0.516903

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039
# 2018-01-04  1.888237 -1.173886  0.247253  0.586609 -0.583093
# 2018-01-05 -1.173853  0.951275  0.344095  1.290251 -0.230119

# %%
df.loc[:, ['B','C','D']]
# Out:
#                    B         C         D
# 2018-01-01  0.378007 -0.534154  0.723208
# 2018-01-02  0.150189 -0.513718  2.314951
# 2018-01-03 -0.782638  0.207020 -1.682846
# 2018-01-04 -1.173886  0.247253  0.586609
# 2018-01-05  0.951275  0.344095  1.290251
# ...              ...       ...       ...
# 2019-08-19 -0.700582 -0.374596  1.583775
# 2019-08-20 -0.026469 -0.355014  1.796853
# 2019-08-21  2.440917 -1.234974  0.195813
# 2019-08-22 -0.318511  0.877091 -0.349808
# 2019-08-23 -0.142352 -1.159747  1.373990
#
# [600 rows x 3 columns]

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039

# %%
f = df.loc['20180301':'20180917', ['A','E']]

# %%
len(f)
# Out:
# 201

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039

# %%
df.iloc[1:4, 1:3]
# Out:
#                    B         C
# 2018-01-02  0.150189 -0.513718
# 2018-01-03 -0.782638  0.207020
# 2018-01-04 -1.173886  0.247253

# %%
df.iloc[[1,5,6], [0, 3]]
# Out:
#                    A         D
# 2018-01-02  0.376292  2.314951
# 2018-01-06  0.258717  0.063986
# 2018-01-07  0.210527  0.582808

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-03 -0.831708 -0.782638  0.207020 -1.682846 -0.013039

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007 -0.534154  0.723208 -0.198661
# 2018-01-02  0.376292  0.150189 -0.513718  2.314951 -0.277246
# 2018-01-04  1.888237 -1.173886  0.247253  0.586609 -0.583093
# 2018-01-06  0.258717 -0.458210  0.561895  0.063986 -0.069068
# 2018-01-07  0.210527  1.068722 -1.311264  0.582808 -0.777233
# ...              ...       ...       ...       ...       ...
# 2019-08-17  0.829120  0.755066  0.174419 -0.576906  0.314580
# 2019-08-19  0.803761 -0.700582 -0.374596  1.583775  0.277284
# 2019-08-20  1.412791 -0.026469 -0.355014  1.796853  0.488986
# 2019-08-21  0.212351  2.440917 -1.234974  0.195813  0.574229
# 2019-08-22  1.033374 -0.318511  0.877091 -0.349808  0.652039
#
# [300 rows x 5 columns]

# %%
df[df > 0]
#
# Out:
#                    A         B         C         D         E
# 2018-01-01  0.098496  0.378007       NaN  0.723208       NaN
# 2018-01-02  0.376292  0.150189       NaN  2.314951       NaN
# 2018-01-03       NaN       NaN  0.207020       NaN       NaN
# 2018-01-04  1.888237       NaN  0.247253  0.586609       NaN
# 2018-01-05       NaN  0.951275  0.344095  1.290251       NaN
# ...              ...       ...       ...       ...       ...
# 2019-08-19  0.803761       NaN       NaN  1.583775  0.277284
# 2019-08-20  1.412791       NaN       NaN  1.796853  0.488986
# 2019-08-21  0.212351  2.440917       NaN  0.195813  0.574229
# 2019-08-22  1.033374       NaN  0.877091       NaN  0.652039
# 2019-08-23       NaN       NaN       NaN  1.373990       NaN
#
# [600 rows x 5 columns]
